# %%
import numpy as np

v = np.array([3,4])

print(v)
# Out:
# [3 4]

# %%
u = np.array([1,2])

v = np.array([3,4])

print(u+v)
# Out:
# [4 6]

# %%
u = np.array([1,2])

v = np.array([3,4])

print(u-v)
# Out:
# [-2 -2]

# %%
v = np.array([2,4])

print(3*v)
# Out:
# [ 6 12]

# %%
u = np.array([2,3])

v = np.array([4,5])

print(np.dot(u,v))
# Out:
# 23

# %%
v = np.array([3,4])

print(np.linalg.norm(v))
# Out:
# 5.0

# %%
v = np.array([3,4])

unit = v / np.linalg.norm(v)

print(unit)
# Out:
# [0.6 0.8]
